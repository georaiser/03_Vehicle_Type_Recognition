# %%
import torch
import torchvision

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, models, transforms
from torchvision.datasets import ImageFolder

from torch.utils.data import DataLoader,Dataset,ConcatDataset
from torchvision.utils import make_grid


import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from matplotlib.image import imread

import time
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.11.0+cpu
# Torchvision Version:  0.12.0+cpu

# %%
path='flowers'
BATCH_SIZE=32
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transfrom = transforms.Compose([
        transforms.RandomResizedCrop(32),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# %%
dataset=ImageFolder(path,transform=transfrom)

train_set,val_set=train_test_split(dataset,test_size=0.2,shuffle=True,random_state=43)

# %%
len(train_set),len(val_set)
# Out:
# (3453, 864)

# %%
train_loader=DataLoader(train_set, batch_size=BATCH_SIZE,shuffle=True)
val_loader=DataLoader(val_set, batch_size=BATCH_SIZE)

# %%
def showimages(imgs,actual_lbls,pred_lbls=None):
    fig = plt.figure(figsize=(21,12))

    for i,img in enumerate(imgs):

        fig.add_subplot(4,8, i+1)
        y=actual_lbls[i]

        if pred_lbls!=None:
            y_pre=pred_lbls[i]
            title="prediction: {0}\nlabel:{1}".format(dataset.classes[y],dataset.classes[y_pre])
        else: 
            title="Label: {0}".format(dataset.classes[y])

        plt.title(title)
        img = img.numpy().transpose((1, 2, 0))
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        img = std * img + mean
        img = np.clip(img, 0, 1)
        plt.axis("off")
        plt.imshow(img)
  
    plt.show()

inputs, classes = next(iter(train_loader))

showimages(inputs,classes)

# %%
model = torchvision.models.resnet18(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features

model.fc = nn.Linear(num_ftrs, len(dataset.classes))

model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

params_to_update = []

for name,param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)

optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)

# %%
from torch.optim import lr_scheduler
# step
step_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
# run model function 
from utils.run_model_pytorch import RunModel
runmodel=RunModel(model, train_loader, val_loader, loss_fn, optimizer_ft, step_scheduler, 'models_save_resnet', n_epochs=20)
accuracies, losses = runmodel.train_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 1 	Training Loss: 1.801724 	Validation Loss: 1.845581
# Epoch: 1 	Training Acc: 20.706632 	Validation Acc: 20.370370
# Validation loss decreased (inf --> 1.845581).  Saving model ...
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 2 	Training Loss: 1.799855 	Validation Loss: 1.860275
# Epoch: 2 	Training Acc: 21.112076 	Validation Acc: 19.675926
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 3 	Training Loss: 1.805611 	Validation Loss: 1.832562
# Epoch: 3 	Training Acc: 21.025195 	Validation Acc: 20.601852
# Validation loss decreased (1.845581 --> 1.832562).  Saving model ...
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 4 	Training Loss: 1.804223 	Validation Loss: 1.859385
# Epoch: 4 	Training Acc: 20.590791 	Validation Acc: 19.097222
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 5 	Training Loss: 1.806103 	Validation Loss: 1.848486
# Epoch: 5 	Training Acc: 21.227918 	Validation Acc: 20.486111
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 6 	Training Loss: 1.796129 	Validation Loss: 1.851575
# Epoch: 6 	Training Acc: 20.677672 	Validation Acc: 19.212963
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 7 	Training Loss: 1.803125 	Validation Loss: 1.848871
# Epoch: 7 	Training Acc: 20.996235 	Validation Acc: 19.907407
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 8 	Training Loss: 1.800328 	Validation Loss: 1.840379
# Epoch: 8 	Training Acc: 21.227918 	Validation Acc: 19.907407
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 9 	Training Loss: 1.796133 	Validation Loss: 1.830769
# Epoch: 9 	Training Acc: 20.648711 	Validation Acc: 18.865741
# Validation loss decreased (1.832562 --> 1.830769).  Saving model ...
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 10 	Training Loss: 1.809558 	Validation Loss: 1.839450
# Epoch: 10 	Training Acc: 21.401680 	Validation Acc: 19.675926
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 11 	Training Loss: 1.802594 	Validation Loss: 1.843950
# Epoch: 11 	Training Acc: 21.372719 	Validation Acc: 18.634259
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 12 	Training Loss: 1.809484 	Validation Loss: 1.829584
# Epoch: 12 	Training Acc: 21.083116 	Validation Acc: 19.675926
# Validation loss decreased (1.830769 --> 1.829584).  Saving model ...
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 13 	Training Loss: 1.806555 	Validation Loss: 1.832424
# Epoch: 13 	Training Acc: 20.793513 	Validation Acc: 20.370370
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 14 	Training Loss: 1.790125 	Validation Loss: 1.855902
# Epoch: 14 	Training Acc: 21.314799 	Validation Acc: 19.444444
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 15 	Training Loss: 1.813005 	Validation Loss: 1.835170
# Epoch: 15 	Training Acc: 20.677672 	Validation Acc: 20.717593
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 16 	Training Loss: 1.798876 	Validation Loss: 1.828031
# Epoch: 16 	Training Acc: 20.272227 	Validation Acc: 20.023148
# Validation loss decreased (1.829584 --> 1.828031).  Saving model ...
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 17 	Training Loss: 1.806278 	Validation Loss: 1.840357
# Epoch: 17 	Training Acc: 20.793513 	Validation Acc: 20.023148
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 18 	Training Loss: 1.803125 	Validation Loss: 1.842147
# Epoch: 18 	Training Acc: 21.546481 	Validation Acc: 19.328704
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 19 	Training Loss: 1.797633 	Validation Loss: 1.856478
# Epoch: 19 	Training Acc: 21.517521 	Validation Acc: 20.138889
# HBox(children=(FloatProgress(value=0.0, max=108.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# Epoch: 20 	Training Loss: 1.804173 	Validation Loss: 1.833957
# Epoch: 20 	Training Acc: 20.214306 	Validation Acc: 21.412037

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(accuracies['train'], label='Training Accuracy')
plt.plot(accuracies['val'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
# plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(losses['train'], label='Training Loss')
plt.plot(losses['val'], label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
def predict_images(model,images,actual_label):
    model.eval()
    with torch.no_grad():
        inputs = images.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        showimages(images,actual_label,preds.cpu())

images, classes = next(iter(val_loader))

predict_images(model,images,classes)
